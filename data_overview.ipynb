# %%
# read in label data
# see how many images, families, and genera are represented
 # download family data and genus data  (fam -> gen -> species)

import pandas as pd
from os import getenv
from dotenv import load_dotenv

load_dotenv()

config = {
    "LABELS_CVS": getenv("LABELS_CVS")
}
labels_csv = config["LABELS_CVS"]

labels_df = pd.read_csv(labels_csv)
labels_df
# Out:
#         ClassId Content      Family    FileName       Genus  \
# 0       81075.0     NaN  Compositae  211959.jpg    Erigeron
# 1       18653.0     NaN    Apiaceae  313649.jpg  Ptilimnium
# 2       81075.0     NaN  Compositae  211971.jpg    Erigeron
# 3       29114.0     NaN     Araceae  379712.jpg  Xanthosoma
# 4       18653.0  Entire    Apiaceae  313646.jpg  Ptilimnium
# ...         ...     ...         ...         ...         ...
# 256282      NaN     NaN         NaN  382042.jpg         NaN
# 256283      NaN     NaN         NaN  382043.jpg         NaN
# 256284      NaN     NaN         NaN  382044.jpg         NaN
# 256285      NaN     NaN         NaN  382045.jpg         NaN
# 256286      NaN     NaN         NaN  382253.jpg         NaN
#
#                                                  ImageUrl  ObservationId  \
# 0       https://plant-or-naw.nyc3.cdn.digitaloceanspac...       137602.0
# 1       https://plant-or-naw.nyc3.cdn.digitaloceanspac...       239292.0
# ...

# %%
import plotly.express as px
# Out:
#              ClassId  ObservationId
# count  251693.000000  251693.000000
# mean   165971.325253  177711.238441
# std     97647.983416   75420.731921
# min        42.000000   46848.000000
# 25%     76922.000000  112546.000000
# 50%    161347.000000  177861.000000
# 75%    256082.000000  243131.000000
# max    331757.000000  307961.000000
